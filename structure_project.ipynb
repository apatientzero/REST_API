# %% [markdown]
# ### Структура проекта

# %%
advertisement_service/
├── app/
│   ├── __init__.py
│   ├── main.py
│   ├── database.py
│   ├── models.py
│   ├── schemas.py
│   └── crud.py
├── Dockerfile
├── docker-compose.yml
└── requirements.txt
